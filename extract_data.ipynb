# %% [markdown]
# Installing the dependencies

# %%
# !pip install openai
# !pip install tiktoken
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.70.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.1.31)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, urldefrag
from collections import deque
import time
import json
import tiktoken
from openai import OpenAI
import os
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
DOMAINS_TO_CRAWL = ['https://iss.ku.edu', 'https://engr.ku.edu', 'https://eecs.ku.edu', 'https://registrar.ku.edu', 'https://catalog.ku.edu']
MAX_DEPTH = 2
RAW_DATA_PATH = 
os.makedirs(RAW_DATA_PATH, exist_ok=True)
QA_DATA_PATH = 
os.makedirs(QA_DATA_PATH, exist_ok=True)

# %% [markdown]
# ## Crawling through the webpages and extracting raw data

# %%
def is_link_valid(url: str, crawl_domain: str) -> bool:
  bad_extensions = (
        ".pdf", ".doc", ".docx", ".ppt", ".pptx", ".xls", ".xlsx",
        ".zip", ".rar", ".gz", ".tar", ".7z",
        ".jpg", ".jpeg", ".png", ".gif", ".bmp", ".svg",
        ".mp4", ".avi", ".mov", ".mp3", ".wav"
  )
  login_auth_redirect = ["/cas", "/login", "/signin", "auth", "session", "returnto"]
  try:
    parsed_url = urlparse(url)
    for keyword in login_auth_redirect:
      if keyword in parsed_url.path or keyword in parsed_url.query:
        return False
    for ext in bad_extensions:
      if parsed_url.path.endswith(ext):
        return False
    domain = parsed_url.netloc.lower()
    if parsed_url.scheme == 'https' and domain.endswith(crawl_domain[9:]):
      return True
    if parsed_url.scheme == 'http' and domain.endswith(crawl_domain[8:]):
      return True
    return False
  except Exception:
    return False

# %%
def get_visible_text(html_content, header_nav_flag):
    # crawl thru header and nav only once
    soup = BeautifulSoup(html_content, "html.parser")
    if header_nav_flag == 0:
      for tag in soup(["script", "style", "noscript"]):
          tag.decompose()
    else:
      for tag in soup(["script", "style", "noscript", "header", "footer", "nav"]):
          tag.decompose()
    main = soup.find("main")
    if main:
      return main.get_text(separator=" ", strip=True)
    return soup.get_text(separator=" ", strip=True)

# %%
def crawl(domain: str):
  urls_visited = set()
  frontier = deque([(domain, 0)])
  enc = tiktoken.encoding_for_model("gpt-4")
  res = []
  total_num_tokens = 0
  total_urls_visited = 0
  header_nav_flag = 0
  print(f'Starting to crawl through {domain} ')

  while frontier:
    url, depth = frontier.popleft()
    if url in urls_visited or depth > MAX_DEPTH:
      continue
    urls_visited.add(url)
    total_urls_visited += 1
    # print(f'Visiting: {url}')

    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
    except Exception as e:
        print(f"Failed to fetch {url}: {e}")
        continue

    text = get_visible_text(response.text, header_nav_flag)
    header_nav_flag = 1
    num_tokens = len(enc.encode(text))
    total_num_tokens += num_tokens
    res.append({"url": url, "text": text, "num_tokens": num_tokens})

    soup = BeautifulSoup(response.text, "html.parser")
    for link in soup.find_all("a", href=True):
        url_to_crawl = urljoin(url, link["href"])
        url_to_crawl, _ = urldefrag(url_to_crawl)
        if is_link_valid(url_to_crawl, domain) and url_to_crawl not in urls_visited:
            frontier.append((url_to_crawl, depth + 1))

    time.sleep(0.5)

  print(f'Total num of pages crawled - {total_urls_visited}')
  print(f'Total num of tokens - {total_num_tokens}')
  return res, total_num_tokens

# %%
total_num_tokens = 0
for domain in DOMAINS_TO_CRAWL:
  crawled_urls_text, num_tokens = crawl(domain)
  total_num_tokens += num_tokens
  with open(f"{RAW_DATA_PATH}{domain[8:].replace('.','_')}.json", "w", encoding="utf-8") as f:
    json.dump(crawled_urls_text, f, indent=2)
  print('')
  time.sleep(5.0)

print('')
print(f'Total num of tokens for all webpages - {total_num_tokens}')
# Out:
# Starting to crawl through https://iss.ku.edu
# Failed to fetch https://iss.ku.edu/node/356: 404 Client Error: Not Found for url: https://iss.ku.edu/node/356
# Failed to fetch https://iss.ku.edu/newly-admitted-ku-ids: 404 Client Error: Not Found for url: https://iss.ku.edu/newly-admitted-ku-ids
# Failed to fetch https://iss.ku.edu/node/353: 404 Client Error: Not Found for url: https://iss.ku.edu/node/353
# Total num of pages crawled - 164
# Total num of tokens - 125815
#
# Starting to crawl through https://engr.ku.edu
# Failed to fetch https://me.engr.ku.edu/faculty-research: HTTPSConnectionPool(host='me.engr.ku.edu', port=443): Max retries exceeded with url: /faculty-research (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'me.engr.ku.edu'. (_ssl.c:1006)")))
# Failed to fetch https://engr.ku.edu/departments-0: 403 Client Error: Forbidden for url: https://engr.ku.edu/departments-0
# Failed to fetch https://engr.ku.edu/eldp: 403 Client Error: Forbidden for url: https://engr.ku.edu/eldp
# Failed to fetch https://engr.ku.edu/engineering-overview-2022: 403 Client Error: Forbidden for url: https://engr.ku.edu/engineering-overview-2022
# Failed to fetch https://engr.ku.edu/mid-career-opportunities: 403 Client Error: Forbidden for url: https://engr.ku.edu/mid-career-opportunities
# Failed to fetch https://engr.ku.edu/resources/studentsupportresources: 403 Client Error: Forbidden for url: https://engr.ku.edu/resources/student-support-resources
# Failed to fetch https://me.engr.ku.edu/mechanical-engineering: HTTPSConnectionPool(host='me.engr.ku.edu', port=443): Max retries exceeded with url: /mechanical-engineering (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'me.engr.ku.edu'. (_ssl.c:1006)")))
# Total num of pages crawled - 486
# Total num of tokens - 279452
#
# Starting to crawl through https://eecs.ku.edu
# Failed to fetch https://eecs.ku.edu/degree-requirements-undergraduate: 403 Client Error: Forbidden for url: https://eecs.ku.edu/degree-requirements-undergraduate
# Failed to fetch https://alian-eecs.ku.edu/: 403 Client Error: Forbidden for url: https://alian-eecs.ku.edu/
# Total num of pages crawled - 160
# Total num of tokens - 144869
#
# Starting to crawl through https://registrar.ku.edu
# Failed to fetch https://registrar.ku.edu/final-exam-schedule: 403 Client Error: Forbidden for url: https://registrar.ku.edu/final-exam-schedule
# Failed to fetch https://registrar.ku.edu/edwardsm@ku.edu: 404 Client Error: Not Found for url: https://registrar.ku.edu/edwardsm@ku.edu
# Total num of pages crawled - 116
# Total num of tokens - 102805
#
# Starting to crawl through https://catalog.ku.edu
# Failed to fetch https://catalog.ku.edu/professional-studies/biotechnology-bas/: 404 Client Error: Not Found for url: https://catalog.ku.edu/professional-studies/biotechnology-bas/
# Failed to fetch https://catalog.ku.edu/architecture/design/book-arts-gcert/: 404 Client Error: Not Found for url: https://catalog.ku.edu/architecture/design/book-arts-gcert/
# Failed to fetch https://catalog.ku.edu/architecture/design/photography-minor/: 404 Client Error: Not Found for url: https://catalog.ku.edu/architecture/design/photography-minor/
# Failed to fetch https://catalog.ku.edu/health-professions/audiology-speech-language-pathology/slpd: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to fetch https://catalog.ku.edu/liberal-arts-sciences/american-studies/asminor: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to fetch https://catalog.ku.edu/liberal-arts-sciences/molecular-biosciences/ma/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to fetch https://catalog.ku.edu/medicine/combined-md-phd: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to fetch https://catalog.ku.edu/medicine/biostatistics/ms: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to fetch https://catalog.ku.edu/medicine/biostatistics/statgradcert: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to fetch https://catalog.ku.edu/medicine/graduate-program-biomedical-sciences: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to fetch https://catalog.ku.edu/medicine/microbiology-molecular-genetics-immunology/phd: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to fetch https://catalog.ku.edu/nursing/certificates/ : 404 Client Error: Not Found for url: https://catalog.ku.edu/nursing/certificates/%20
# Total num of pages crawled - 4670
# Total num of tokens - 4889005
#
#
# Total num of tokens for all webpages - 5541946

# %% [markdown]
# Total num of tokens - 236974 + 135571 + 67943 + 109610 + 1088978 = 1639076

# %% [markdown]
# ## Generating questions, answers, context from raw data

# %%
system_prompt = (
    "You are a knowledgeable assistant trained to extract Q&A from university-related text data. "
    "Your goal is to identify and surface overlooked or under-discussed information from the passage. "
    # "Avoid common and frequently asked topics like admissions, visas, application deadlines, or department overviews unless there is something truly novel."
)

user_prompt_template = """Given the following passage and URL, generate 3 to 5 high-quality question-answer (Q&A) pairs that are:

- Fresh and unique: Prioritize lesser-known or underused aspects of the passage.
- Factual and grounded: Base everything strictly on the given text.
- Diverse and non-redundant: Cover different ideas without overlap.
- Clearly supported: Include a supporting excerpt from the text as 'context'.

Each Q&A pair must have:
- question: A clear, specific question based on the content.
- answer: A concise, factually correct answer from the passage.
- context: A supporting excerpt from the passage.
- source: The URL of the passage.

Avoid repeating topics across questions. Focus especially on detailed points that are easy to overlook but still valuable to know.

Passage:
{text}

Source:
{url}

Return the output as a JSON array, where each item has:
- question: the question text
- answer: the answer text
- context: the supporting excerpt from the text
- source: the original URL

Example format:
[
  {{
    "question": "...",
    "answer": "...",
    "context": "...",
    "source": "{url}"
  }},
  ...
]
Output only the JSON array in the right format. Do not include anything before or after it.
"""

url= "https://iss.ku.edu/f-1-transfer"
text= "F-1 Transfer All students currently in F-1 status at any type of institution (high school, college, university, intensive English institute) in the U.S. (including those on Optional Practical Training) who plan to change schools must complete the transfer procedure through SEVIS.\u00a0 It is the student\u2019s responsibility to maintain his or her F-1 student status and to complete the procedures below. Transfer Procedure Complete admission to the University of Kansas. Only after you have decided to attend KU: Notify your current school (or if on Optional Practical Training your former school who recommended the OPT) of your intent to transfer to KU. Speak with an international student advisor at your current school to request the release of your SEVIS (I-20) record to KU and set the date for the release of your record. To release your SEVIS record to the University of Kansas, your advisor will need KU\u2019s SEVIS school code: KAN214F00634000. Complete and submit the \"Intent to Transfer to KU\" e-form online: Step 1 \u2013 Setup KU Online ID (you will need your 7-digit KUID number [e.g. 2991234]) Step 2 \u2013 Log in to iHawk by using the blue \u201cLogin\u201d button. Step 3 \u2013 Complete and submit the \u201cIntent to Transfer to KU from a U.S. School\u201d e-form, under the \u201cGet Your I-20/DS-2019\u201d tab.\u00a0 You will need to provide the email address of your current international student advisor at the transfer-out school and any Reduced Course Load (RCL) information. After the release date, KU will produce an I-20 if all e-forms have been completed and approved. KU cannot produce the I-20 before the release date . Once the I-20 is issued, you will receive it in the manner which you selected in iHawk. To complete the transfer, you are required to report to an international student advisor at KU within 15 days of the report date on your new KU I-20, during orientation or at an ISS Check-in session. Driver License & SSN Issues Your transferred in SEVIS record is typically not registered (changed to active status) until orientation/ISS Check-ins are completed, you have enrolled, and classes have started.\u00a0 If you can, you should wait to apply for your driver\u2019s license or social security number until after classes have started.\u00a0 If you absolutely cannot wait, consult the ISS office. Re-admitted Students, Transferring Back to KU Checklist of things to do: Have your SEVIS record released (transferred) to KU: See instructions above Complete a required ISS Check In: As a readmitted student, you are not required (although certainly welcome) to attend the International Student Orientation, however, you are still required to complete the ISS Check-in. Review the details on Readmitted Student Arrival and Check-in Processes ."

user_prompt = user_prompt_template.format(text=text.strip(), url=url)
print(user_prompt)
# Out:
# Given the following passage and URL, generate 3 to 5 high-quality question-answer (Q&A) pairs that are:
#
# - Fresh and unique: Prioritize lesser-known or underused aspects of the passage.
# - Factual and grounded: Base everything strictly on the given text.
# - Diverse and non-redundant: Cover different ideas without overlap.
# - Clearly supported: Include a supporting excerpt from the text as 'context'.
#
# Each Q&A pair must have:
# - question: A clear, specific question based on the content.
# - answer: A concise, factually correct answer from the passage.
# - context: A supporting excerpt from the passage.
# - source: The URL of the passage.
#
# Avoid repeating topics across questions. Focus especially on detailed points that are easy to overlook but still valuable to know.
#
# Passage:
# F-1 Transfer All students currently in F-1 status at any type of institution (high school, college, university, intensive English institute) in the U.S. (including those on Optional Practical Training) who plan to change schools must complete the transfer procedure through SEVIS.  It is the student’s responsibility to maintain his or her F-1 student status and to complete the procedures below. Transfer Procedure Complete admission to the University of Kansas. Only after you have decided to attend KU: Notify your current school (or if on Optional Practical Training your former school who recommended the OPT) of your intent to transfer to KU. Speak with an international student advisor at your current school to request the release of your SEVIS (I-20) record to KU and set the date for the release of your record. To release your SEVIS record to the University of Kansas, your advisor will need KU’s SEVIS school code: KAN214F00634000. Complete and submit the "Intent to Transfer to KU" e-form online: Step 1 – Setup KU Online ID (you will need your 7-digit KUID number [e.g. 2991234]) Step 2 – Log in to iHawk by using the blue “Login” button. Step 3 – Complete and submit the “Intent to Transfer to KU from a U.S. School” e-form, under the “Get Your I-20/DS-2019” tab.  You will need to provide the email address of your current international student advisor at the transfer-out school and any Reduced Course Load (RCL) information. After the release date, KU will produce an I-20 if all e-forms have been completed and approved. KU cannot produce the I-20 before the release date . Once the I-20 is issued, you will receive it in the manner which you selected in iHawk. To complete the transfer, you are required to report to an international student advisor at KU within 15 days of the report date on your new KU I-20, during orientation or at an ISS Check-in session. Driver License & SSN Issues Your transferred in SEVIS record is typically not registered (changed to active status) until orientation/ISS Check-ins are completed, you have enrolled, and classes have started.  If you can, you should wait to apply for your driver’s license or social security number until after classes have started.  If you absolutely cannot wait, consult the ISS office. Re-admitted Students, Transferring Back to KU Checklist of things to do: Have your SEVIS record released (transferred) to KU: See instructions above Complete a required ISS Check In: As a readmitted student, you are not required (although certainly welcome) to attend the International Student Orientation, however, you are still required to complete the ISS Check-in. Review the details on Readmitted Student Arrival and Check-in Processes .
#
# Source:
# https://iss.ku.edu/f-1-transfer
#
# Return the output as a JSON array, where each item has:
# - question: the question text
# - answer: the answer text
# - context: the supporting excerpt from the text
# - source: the original URL
#
# Example format:
# [
#   {
#     "question": "...",
#     "answer": "...",
#     "context": "...",
#     "source": "https://iss.ku.edu/f-1-transfer"
#   },
#   ...
# ]
# Output only the JSON array in the right format. Do not include anything before or after it.

# %%
client = OpenAI(
  api_key = OPENAI_API_KEY
)

completion = client.chat.completions.create(
  model="gpt-4o-mini",
  store=True,
  messages=[
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
  ]
)
print(completion.choices[0].message);

# %%
for filename in os.listdir(RAW_DATA_PATH):
  with open(f"{RAW_DATA_PATH}{filename}", "r", encoding="utf-8") as f:
    data = json.load(f)
  res = []
  print(f'Gnerating Q&As for {filename}')
  for item in data:
    url = item['url']
    text = item['text']
    num_tokens = item['num_tokens']
    user_prompt = user_prompt_template.format(text=text.strip(), url=url)

    # print(f'  Generating Q&As for {url}')
    client = OpenAI(
    api_key = OPENAI_API_KEY
    )
    try:
      completion = client.chat.completions.create(
        model="gpt-4o-mini",
        store=True,
        messages=[
          {"role": "system", "content": system_prompt},
          {"role": "user", "content": user_prompt}
        ]
      )
      raw_output = completion.choices[0].message.content
      raw_output = raw_output.strip().replace("```json", "").replace("```", "").strip()
      output = json.loads(raw_output)
      res.extend(output)
    except Exception as e:
      print(f'Failed to generate prompts for: {e}')

    time.sleep(1.5)

  with open(f'{QA_DATA_PATH}{filename}', "w", encoding="utf-8") as f:
          json.dump(res, f, indent=2)
# Out:
# Generating Q&As for https://engr.ku.edu
# Generating Q&As for https://engr.ku.edu/navigator
# Generating Q&As for https://engr.ku.edu/
# Generating Q&As for https://engr.ku.edu/about
# Generating Q&As for https://engr.ku.edu/visit-us
# Generating Q&As for https://engr.ku.edu/our-mission
# Generating Q&As for https://engr.ku.edu/explore
# Generating Q&As for https://engr.ku.edu/facilities-maps
# Generating Q&As for https://engr.ku.edu/recognition-ceremonies
# Generating Q&As for https://engr.ku.edu/news
# Generating Q&As for https://engr.ku.edu/alumni-friends
# Generating Q&As for https://engr.ku.edu/history
# Generating Q&As for https://engr.ku.edu/contact-ku-school-engineering
# Generating Q&As for https://engr.ku.edu/academics
# Generating Q&As for https://engr.ku.edu/departments
# Generating Q&As for http://bio.engr.ku.edu/
# Generating Q&As for http://cpe.engr.ku.edu/
# Generating Q&As for http://ephx.engr.ku.edu/
# Generating Q&As for https://engr.ku.edu/current-undergraduate-students
# Generating Q&As for https://engr.ku.edu/academic-standing
# Generating Q&As for https://engr.ku.edu/engineering-student-resources/academic-misconduct
# Generating Q&As for https://engr.ku.edu/advising
# Generating Q&As for https://engr.ku.edu/engineering-student-resources
# Generating Q&As for https://engr.ku.edu/undergraduate-graduation-info
# Generating Q&As for https://engr.ku.edu/student-involvement
# Generating Q&As for https://engr.ku.edu/forms
# Generating Q&As for https://engr.ku.edu/research-and-graduate-programs
# Generating Q&As for https://engr.ku.edu/graduate-academic-resources
# Generating Q&As for https://engr.ku.edu/graduate-enrollment-info
# Generating Q&As for https://engr.ku.edu/graduate-engineering-association
# Generating Q&As for https://engr.ku.edu/gea-travel-grant
# Generating Q&As for https://engr.ku.edu/gea-research-showcase
# Generating Q&As for https://engr.ku.edu/graduate-student-orientation
# Generating Q&As for https://engr.ku.edu/graduate-graduation
# Generating Q&As for https://engr.ku.edu/plan-study
# Generating Q&As for https://engr.ku.edu/progress-toward-degree
# Generating Q&As for https://engr.ku.edu/public-disclosure-requirements-licensure-programs
# Generating Q&As for https://engr.ku.edu/international-experiences-ku-school-engineering
# Generating Q&As for https://engr.ku.edu/admission
# Generating Q&As for https://engr.ku.edu/admission-requirements
# Generating Q&As for https://engr.ku.edu/after-admission
# Generating Q&As for https://engr.ku.edu/undergraduate-research
# Generating Q&As for https://engr.ku.edu/ku-engineering-graduate-school
# Generating Q&As for https://engr.ku.edu/grad-experience
# Generating Q&As for https://engr.ku.edu/graduate-programs
# Generating Q&As for https://engr.ku.edu/grad-funding
# Generating Q&As for https://engr.ku.edu/research
# Generating Q&As for https://bioengr.ku.edu/research
# Generating Q&As for https://engr.ku.edu/broadening-participation-graduate
# Generating Q&As for https://engr.ku.edu/research-areas-department
# Generating Q&As for https://engr.ku.edu/news-faculty-leaders-and-research-support
# Generating Q&As for https://engr.ku.edu/industry-research-partners
# Generating Q&As for https://engr.ku.edu/research-centers
# Generating Q&As for https://engr.ku.edu/research-innovations
# Generating Q&As for https://engr.ku.edu/research-funding
# Generating Q&As for https://engr.ku.edu/faculty-funding
# Generating Q&As for https://engr.ku.edu/graduate-scholarly-presentation-travel-award
# Generating Q&As for https://engr.ku.edu/school-engineering-proposals
# Generating Q&As for https://engr.ku.edu/orgs
# Generating Q&As for https://engr.ku.edu/undergraduate-engineering-ambassadors
# Generating Q&As for https://engr.ku.edu/engineering-student-council
# Generating Q&As for https://engr.ku.edu/student-organization-funding
# Generating Q&As for https://engr.ku.edu/student-organization-resources
# Generating Q&As for https://engr.ku.edu/scholarships
# Generating Q&As for https://engr.ku.edu/impact-and-belonging-scholarships
# Generating Q&As for https://engr.ku.edu/graduate-scholarships
# Generating Q&As for https://engr.ku.edu/undergraduate-scholarships
# Generating Q&As for https://engr.ku.edu/self-engineering-leadership-fellows-program
# Generating Q&As for https://engr.ku.edu/self-program-history
# Generating Q&As for https://engr.ku.edu/self-fellows
# Generating Q&As for https://engr.ku.edu/self-program-faq
# Generating Q&As for https://engr.ku.edu/high-school-design-competition
# Generating Q&As for https://engr.ku.edu/self-on-the-road
# Generating Q&As for https://engr.ku.edu/self-fellow-responsibilities
# Generating Q&As for https://engr.ku.edu/apply-self-program
# Generating Q&As for https://engr.ku.edu/impact-and-belonging
# Generating Q&As for https://engr.ku.edu/pre-college-programs
# Generating Q&As for https://engr.ku.edu/impact-and-belonging-student-organizations
# Generating Q&As for https://engr.ku.edu/campus-student-resources
# Generating Q&As for https://engr.ku.edu/impact-history
# Generating Q&As for https://engr.ku.edu/people
# Generating Q&As for https://engr.ku.edu/resources
# Generating Q&As for https://engr.ku.edu/remote-lab-access
# Generating Q&As for https://engr.ku.edu/room-reservation-request
# Generating Q&As for https://engr.ku.edu/safety
# Generating Q&As for https://engr.ku.edu/newsletterdigital-signage-submission
# Generating Q&As for https://engr.ku.edu/enrollment-and-graduation-data
# Generating Q&As for https://engr.ku.edu/engr-it-alerts
# Generating Q&As for https://engr.ku.edu/technology-service-center
# Generating Q&As for https://engr.ku.edu/computer-specs
# Generating Q&As for https://engr.ku.edu/software-request
# Generating Q&As for https://engr.ku.edu/news/article/university-of-kansas-awarded-26-million-for-new-engineering-research-center-from-us-national-science-foundation
# Generating Q&As for https://engr.ku.edu/node/2785
# Generating Q&As for https://bioengr.ku.edu
# Generating Q&As for https://engr.ku.edu/node/2787
# Generating Q&As for https://engr.ku.edu/node/2789
# Generating Q&As for https://engr.ku.edu/node/2786
# Generating Q&As for https://engr.ku.edu/node/2791
# Generating Q&As for https://engr.ku.edu/node/2792
# Generating Q&As for https://engr.ku.edu/node/2790
# Generating Q&As for https://engr.ku.edu/node/2788
# Generating Q&As for https://engr.ku.edu/news/article/engineering-professor-named-aaas-fellow
# Generating Q&As for https://engr.ku.edu/news/article/expo-showcases-the-wonders-of-ku-engineering
# Generating Q&As for http://bioengr.ku.edu/
# Generating Q&As for https://engr.ku.edu/recognition-ceremony
# Generating Q&As for https://engr.ku.edu/open-house-engineering-graduate-programs
# Generating Q&As for https://engr.ku.edu/camps
# Generating Q&As for https://engr.ku.edu/engineering-expo
# Generating Q&As for https://engr.ku.edu/engineering-showcase-series-2023
# Generating Q&As for https://engr.ku.edu/events
# Generating Q&As for https://engr.ku.edu/news/article/engineering-faculty-member-wins-prestigious-early-career-presidential-award
# Generating Q&As for https://engr.ku.edu/news/article/ku-strengthening-national-defense-partnership-with-new-office
# Generating Q&As for https://engr.ku.edu/locke-and-gould-awards
# Generating Q&As for https://engr.ku.edu/people/claire-harding
# Generating Q&As for https://engr.ku.edu/people/alex-pang
# Generating Q&As for https://engr.ku.edu/people/tracy-rockers
# Generating Q&As for https://engr.ku.edu/news/article/aerospace-engineer-ron-barrett-gonzalez-named-national-academy-of-inventors-fellow
# Generating Q&As for https://engr.ku.edu/news/article/ku-engineering-signs-agreement-with-us-cybercommand-to-aid-in-cybersecurity-efforts
# Generating Q&As for https://engr.ku.edu/news/article/new-5-million-doe-award-supports-ku-startups-green-hydrogen-energy-research
# Generating Q&As for https://engr.ku.edu/news/article/engineering-a-better-future-ku-school-of-engineering-hosts-annual-stem-competition-for-high-school-students
# Generating Q&As for https://engr.ku.edu/news/article/new-ku-engineering-ihawke-student-lounge-named-for-joyce-and-mike-shinn
# Generating Q&As for https://engr.ku.edu/news/article/research-will-establish-best-managed-retreat-practices-for-communities-faced-with-climate-change-disaster
# Generating Q&As for https://engr.ku.edu/news/article/panasonic-energy-and-university-of-kansas-to-collaborate-on-ev-battery-technology-and-talent-development
# Generating Q&As for https://engr.ku.edu/news/article/ku-engineering-associate-dean-recognized-nationally-for-leadership-and-mentoring
# Generating Q&As for https://engr.ku.edu/news/article/ku-aerospace-engineering-launches-first-cubesat-into-orbit
# Generating Q&As for https://engr.ku.edu/news/article/i2s-scientist-receives-nsf-award-for-research-focused-on-cardiac-tissue-ablations
# Generating Q&As for https://engr.ku.edu/news/article/2024/04/24/jayhawk-astronaut-connects-ku-students-space
# Generating Q&As for https://engr.ku.edu/news/article/ku-engineering-to-honor-2-alumni-with-distinguished-engineering-service-award
# Generating Q&As for https://engr.ku.edu/news/article/three-ku-professors-of-chemistry-economics-and-engineering-named-aaas-fellows
# Generating Q&As for https://engr.ku.edu/news/article/icorium-engineering-company-earns-top-5-finish-at-2024-rice-business-plan-competition
# Generating Q&As for https://engr.ku.edu/news/article/2024/04/02/alumni-profile-kevin-cunningham
# Generating Q&As for https://engr.ku.edu/news/article/2024/04/01/two-ku-engineering-professors-recognized-early-career-research-success
# Generating Q&As for https://engr.ku.edu/news/article/2024/02/27/ku-engineering-professor-wins-nsf-career-award-research-wetlands-water-quality-benefits
# Generating Q&As for https://engr.ku.edu/news/article/2024/02/27/ku-engineering-professor-wins-nsf-career-award-water-resources-research
# Generating Q&As for https://engr.ku.edu/news/article/ku-senior-from-kansas-city-awarded-full-ride-to-university-of-cambridge-to-pursue-sustainable-engineering
# Generating Q&As for https://engr.ku.edu/news/article/university-of-kansas-renames-institute-for-sustainable-engineering-after-the-wonderful-company
# Generating Q&As for https://engr.ku.edu/loral-ohara-live-qa-international-space-station
# Generating Q&As for https://engr.ku.edu/news/article/2024/01/08/engineering-professor-receives-darpa-grant-research-radar-signal-processing
# Generating Q&As for https://engr.ku.edu/news/article/2023/12/12/google-earth-creator-brian-mcclendon-kus-newest-national-academy-inventors-fellow
# Generating Q&As for https://engr.ku.edu/news/article/2023/12/07/mary-rezac-named-new-dean-ku-school-engineering
# Generating Q&As for https://engr.ku.edu/news/article/2023/11/13/ku-engineering-partner-4-million-department-defense-grant
# Generating Q&As for https://engr.ku.edu/news?page=1
# Generating Q&As for https://engr.ku.edu/news?page=2
# Generating Q&As for https://engr.ku.edu/news?page=3
# Generating Q&As for https://engr.ku.edu/news?page=4
# Generating Q&As for https://engr.ku.edu/news?page=5
# Generating Q&As for https://engr.ku.edu/news?page=20
# Generating Q&As for https://engr.ku.edu/desa-nomination
# Generating Q&As for https://engr.ku.edu/desa
# Generating Q&As for https://engr.ku.edu/school-engineering-advisory-board
# Generating Q&As for https://engr.ku.edu/current-graduate-students
# Generating Q&As for https://engr.ku.edu/self
# Generating Q&As for https://engr.ku.edu/aerospace-engineering-brochure-2023
# Generating Q&As for https://engr.ku.edu/bioengineering-brochure-2023
# Generating Q&As for https://engr.ku.edu/chemical-engineering-brochure-2023
# Generating Q&As for https://engr.ku.edu/petroleum-engineering-brochure-2023
# Generating Q&As for https://engr.ku.edu/civil-environmental-architectural-engineering-brochure-2023
# Generating Q&As for https://engr.ku.edu/electrical-engineering-computer-science-brochure-2023
# Generating Q&As for https://engr.ku.edu/engineering-physics-brochure-2023
# Generating Q&As for http://me.engr.ku.edu/
# Generating Q&As for https://engr.ku.edu/mechanical-engineering-brochure-2023
# Generating Q&As for http://bio.engr.ku.edu/navigator
# Generating Q&As for http://engr.ku.edu/
# Generating Q&As for http://bio.engr.ku.edu/vision-mission
# Generating Q&As for http://bio.engr.ku.edu/community
# Generating Q&As for http://bio.engr.ku.edu/contact
# Generating Q&As for http://bio.engr.ku.edu/faqs
# Generating Q&As for http://bio.engr.ku.edu/funding
# Generating Q&As for http://bio.engr.ku.edu/beyond-ku
# Generating Q&As for http://bio.engr.ku.edu/entrance-requirements-track
# Generating Q&As for http://bio.engr.ku.edu/application
# Generating Q&As for http://bio.engr.ku.edu/overview
# Generating Q&As for http://bio.engr.ku.edu/ms
# Generating Q&As for http://bio.engr.ku.edu/accelerated-ms
# Generating Q&As for http://bio.engr.ku.edu/master-engineering
# Generating Q&As for http://bio.engr.ku.edu/phd
# Generating Q&As for http://bio.engr.ku.edu/bioengineering-graduate-programs-2024-25
# Generating Q&As for http://bio.engr.ku.edu/bioengineering-courses
# Generating Q&As for http://bio.engr.ku.edu/bioimaging
# Generating Q&As for http://bio.engr.ku.edu/biomaterials-tissue-engineering
# Generating Q&As for http://bio.engr.ku.edu/biomechanics-neural-engineering
# Generating Q&As for http://bio.engr.ku.edu/biomedical-product-design-development
# Generating Q&As for http://bio.engr.ku.edu/biomolecular-engineering
# Generating Q&As for http://bio.engr.ku.edu/computational-bioengineering
# Generating Q&As for http://bio.engr.ku.edu/degree-requirements
# Generating Q&As for http://bio.engr.ku.edu/forms-documents
# Generating Q&As for http://bio.engr.ku.edu/graduating
# Generating Q&As for http://bio.engr.ku.edu/biomedical-product-design-certificate
# Generating Q&As for http://bio.engr.ku.edu/undergraduate-certificate
# Generating Q&As for http://bio.engr.ku.edu/minor-biomedical-engineering
# Generating Q&As for http://bio.engr.ku.edu/people/search
# Generating Q&As for http://bio.engr.ku.edu/leadership
# Generating Q&As for http://bio.engr.ku.edu/core-faculty
# Generating Q&As for http://bio.engr.ku.edu/academic-affiliates
# Generating Q&As for http://bio.engr.ku.edu/clinical-affiliates
# Generating Q&As for http://bio.engr.ku.edu/graduate-students
# Generating Q&As for http://bio.engr.ku.edu/staff
# Generating Q&As for http://bio.engr.ku.edu/research
# Generating Q&As for http://bio.engr.ku.edu/colloquium
# Generating Q&As for http://bio.engr.ku.edu/events
# Generating Q&As for http://bio.engr.ku.edu/opportunities
# Generating Q&As for http://bio.engr.ku.edu/rising-bme-scholars-conference
# Generating Q&As for http://bio.engr.ku.edu/donate
# Generating Q&As for https://bioengr.ku.edu/rising-bme-scholars-conference
# Generating Q&As for http://cpe.engr.ku.edu/navigator
# Generating Q&As for http://cpe.engr.ku.edu/chairs-welcome
# Generating Q&As for http://cpe.engr.ku.edu/about-us
# Generating Q&As for http://cpe.engr.ku.edu/accreditation
# Generating Q&As for http://cpe.engr.ku.edu/research-areas
# Generating Q&As for http://cpe.engr.ku.edu/research-centers
# Generating Q&As for http://cpe.engr.ku.edu/undergraduate-research
# Generating Q&As for http://cpe.engr.ku.edu/reu
# Generating Q&As for http://cpe.engr.ku.edu/reu-alumni
# Generating Q&As for http://cpe.engr.ku.edu/research-productivity
# Generating Q&As for http://cpe.engr.ku.edu/forms
# Generating Q&As for http://cpe.engr.ku.edu/faculty
# Generating Q&As for http://cpe.engr.ku.edu/staff-profiles
# Generating Q&As for http://cpe.engr.ku.edu/adjunct-professors-and-lecturers
# Generating Q&As for http://cpe.engr.ku.edu/advisory-board
# Generating Q&As for http://cpe.engr.ku.edu/graduate-students
# Generating Q&As for http://cpe.engr.ku.edu/emeriti-professors
# Generating Q&As for http://cpe.engr.ku.edu/courtesy-faculty
# Generating Q&As for http://cpe.engr.ku.edu/about-undergraduate
# Generating Q&As for http://cpe.engr.ku.edu/undergraduate-admissions
# Generating Q&As for http://cpe.engr.ku.edu/undergraduate-advising
# Generating Q&As for http://cpe.engr.ku.edu/degrees-and-curriculum
# Generating Q&As for http://cpe.engr.ku.edu/degree-chemical
# Generating Q&As for http://cpe.engr.ku.edu/degree-petroleum
# Generating Q&As for http://cpe.engr.ku.edu/enrollment-resources
# Generating Q&As for http://cpe.engr.ku.edu/teaching-labs
# Generating Q&As for http://cpe.engr.ku.edu/research-and-job-opportunities
# Generating Q&As for http://cpe.engr.ku.edu/resources-undergraduate
# Generating Q&As for http://cpe.engr.ku.edu/student-involvement-and-professional-organizations
# Generating Q&As for http://cpe.engr.ku.edu/graduate-admissions
# Generating Q&As for http://cpe.engr.ku.edu/degrees
# Generating Q&As for http://cpe.engr.ku.edu/enrollment-resources-and-course-listings
# Generating Q&As for http://cpe.engr.ku.edu/opportunities
# Generating Q&As for http://cpe.engr.ku.edu/resources-students-graduate
# Generating Q&As for http://cpe.engr.ku.edu/seminar
# Generating Q&As for http://cpe.engr.ku.edu/graduate-defenses
# Generating Q&As for http://cpe.engr.ku.edu/chemical-engineering-graduate-programs-2024-25
# Generating Q&As for http://cpe.engr.ku.edu/petroleum-engineering-graduate-programs-2024-25
# Generating Q&As for http://cpe.engr.ku.edu/alumni-engagement
# Generating Q&As for http://cpe.engr.ku.edu/hall-fame
# Generating Q&As for http://cpe.engr.ku.edu/alumni-profiles
# Generating Q&As for http://cpe.engr.ku.edu/cpe-news
# Generating Q&As for http://cpe.engr.ku.edu/cpe-events
# Generating Q&As for http://cpe.engr.ku.edu/news-event-submission
# Generating Q&As for http://cpe.engr.ku.edu/cpe-videos
# Generating Q&As for http://cpe.engr.ku.edu/cpe-newsletters
# Generating Q&As for http://cpe.engr.ku.edu/chemical-engineering
# Generating Q&As for http://cpe.engr.ku.edu/petroleum-engineering
# Generating Q&As for http://cpe.engr.ku.edu/news
# Generating Q&As for http://cpe.engr.ku.edu/cpe-images
# Generating Q&As for http://cpe.engr.ku.edu/degrees-curriculum
# Generating Q&As for http://cpe.engr.ku.edu/department-news
# Generating Q&As for http://cpe.engr.ku.edu/videos
# Generating Q&As for http://ephx.engr.ku.edu/navigator
# Generating Q&As for http://ephx.engr.ku.edu/contact
# Generating Q&As for http://ephx.engr.ku.edu/welcome-and-mission
# Generating Q&As for http://ephx.engr.ku.edu/accreditation
# Generating Q&As for http://ephx.engr.ku.edu/advising
# Generating Q&As for http://ephx.engr.ku.edu/courses
# Generating Q&As for http://ephx.engr.ku.edu/degree-concentrations
# Generating Q&As for http://ephx.engr.ku.edu/aerospace-systems
# Generating Q&As for http://ephx.engr.ku.edu/chemical-systems
# Generating Q&As for http://ephx.engr.ku.edu/digital-electronic-systems
# Generating Q&As for http://ephx.engr.ku.edu/electromechanical-control-systems
# Generating Q&As for http://ephx.engr.ku.edu/departmental-honors
# Generating Q&As for http://ephx.engr.ku.edu/program-statements
# Generating Q&As for http://ephx.engr.ku.edu/admissions
# Generating Q&As for http://ephx.engr.ku.edu/research
# Generating Q&As for http://ephx.engr.ku.edu/people/list/faculty
# Generating Q&As for http://ephx.engr.ku.edu/people/list/staff
# Generating Q&As for http://ephx.engr.ku.edu/alumni-friends
# Generating Q&As for http://ephx.engr.ku.edu/faqs
# Generating Q&As for http://ephx.engr.ku.edu/information-prospective-students
# Generating Q&As for https://engr.ku.edu/academic-resources
# Generating Q&As for https://engr.ku.edu/advising/degree-plans
# Generating Q&As for https://bioengr.ku.edu/
# Generating Q&As for https://engr.ku.edu/advising/advising-enrollment-policies
# Generating Q&As for https://engr.ku.edu/campus-student-resources-deib
# Generating Q&As for https://engr.ku.edu/reu
# Generating Q&As for https://engr.ku.edu/engineering-study-abroad
# Generating Q&As for https://engr.ku.edu/people/ashish-adhikari
# Generating Q&As for https://engr.ku.edu/people/connor-ahlquist
# Generating Q&As for https://engr.ku.edu/people/afeez-badmus
# Generating Q&As for https://engr.ku.edu/people/samyoga-bhattarai
# Generating Q&As for https://engr.ku.edu/people/yousif-dafalla
# Generating Q&As for https://engr.ku.edu/people/julia-emilia-espinoza-mejia
# Generating Q&As for https://engr.ku.edu/people/valerie-griffin
# Generating Q&As for https://engr.ku.edu/people/gideon-gyamfi
# Generating Q&As for https://engr.ku.edu/people/willy-lee
# Generating Q&As for https://engr.ku.edu/people/promise-o-longe
# Generating Q&As for https://engr.ku.edu/people/jordan-nutter
# Generating Q&As for https://engr.ku.edu/people/ibilola-ogundare
# Generating Q&As for https://engr.ku.edu/people/soma-pal
# Generating Q&As for https://engr.ku.edu/people/kabir-panahi
# Generating Q&As for https://engr.ku.edu/people/joao-victor-poli
# Generating Q&As for https://engr.ku.edu/people/koyel-pramanick
# Generating Q&As for https://engr.ku.edu/people/orion-roach
# Generating Q&As for https://engr.ku.edu/people/mona-shaheen
# Generating Q&As for https://engr.ku.edu/people/mahgam-tabatabaei
# Generating Q&As for https://engr.ku.edu/people/lu-zhao
# Generating Q&As for http://gradplan.engr.ku.edu/
# Generating Q&As for https://engr.ku.edu/school-engineering-graduate-program-timeline
# Generating Q&As for https://engr.ku.edu/masters-program-timeline
# Generating Q&As for https://engr.ku.edu/student-advisor-expectations
# Generating Q&As for https://engr.ku.edu/engineering-learning-community
# Generating Q&As for https://engr.ku.edu/undergraduate-research-faq
# Generating Q&As for https://engr.ku.edu/undergraduate-research-fellows
# Generating Q&As for https://engr.ku.edu/graduate-recruitment-schedule
# Generating Q&As for http://me.engr.ku.edu/faculty-research
# Generating Q&As for https://engr.ku.edu/deans-first-year-doctoral-fellowship
# Generating Q&As for https://engr.ku.edu/news-honors-initiatives
# Generating Q&As for https://bioengr.ku.edu/navigator
# Generating Q&As for https://bioengr.ku.edu/vision-mission
# Generating Q&As for https://bioengr.ku.edu/community
# Generating Q&As for https://bioengr.ku.edu/contact
# Generating Q&As for https://bioengr.ku.edu/faqs
# Generating Q&As for https://bioengr.ku.edu/funding
# Generating Q&As for https://bioengr.ku.edu/beyond-ku
# Generating Q&As for https://bioengr.ku.edu/entrance-requirements-track
# Generating Q&As for https://bioengr.ku.edu/application
# Generating Q&As for https://bioengr.ku.edu/overview
# Generating Q&As for https://bioengr.ku.edu/ms
# Generating Q&As for https://bioengr.ku.edu/accelerated-ms
# Generating Q&As for https://bioengr.ku.edu/master-engineering
# Generating Q&As for https://bioengr.ku.edu/phd
# Generating Q&As for https://bioengr.ku.edu/bioengineering-graduate-programs-2024-25
# Generating Q&As for https://bioengr.ku.edu/bioengineering-courses
# Generating Q&As for https://bioengr.ku.edu/bioimaging
# Generating Q&As for https://bioengr.ku.edu/biomaterials-tissue-engineering
# Generating Q&As for https://bioengr.ku.edu/biomechanics-neural-engineering
# Generating Q&As for https://bioengr.ku.edu/biomedical-product-design-development
# Generating Q&As for https://bioengr.ku.edu/biomolecular-engineering
# Generating Q&As for https://bioengr.ku.edu/computational-bioengineering
# Generating Q&As for https://bioengr.ku.edu/degree-requirements
# Generating Q&As for https://bioengr.ku.edu/forms-documents
# Generating Q&As for https://bioengr.ku.edu/graduating
# Generating Q&As for https://bioengr.ku.edu/biomedical-product-design-certificate
# Generating Q&As for https://bioengr.ku.edu/undergraduate-certificate
# Generating Q&As for https://bioengr.ku.edu/minor-biomedical-engineering
# Generating Q&As for https://bioengr.ku.edu/people/search
# Generating Q&As for https://bioengr.ku.edu/leadership
# Generating Q&As for https://bioengr.ku.edu/core-faculty
# Generating Q&As for https://bioengr.ku.edu/academic-affiliates
# Generating Q&As for https://bioengr.ku.edu/clinical-affiliates
# Generating Q&As for https://bioengr.ku.edu/graduate-students
# Generating Q&As for https://bioengr.ku.edu/staff
# Generating Q&As for https://bioengr.ku.edu/colloquium
# Generating Q&As for https://bioengr.ku.edu/events
# Generating Q&As for https://bioengr.ku.edu/opportunities
# Generating Q&As for https://bioengr.ku.edu/donate
# Generating Q&As for https://bioengr.ku.edu/people
# Generating Q&As for https://engr.ku.edu/aerospace-engineering-facilities
# Generating Q&As for https://engr.ku.edu/bioengineering-facilities
# Generating Q&As for https://engr.ku.edu/chemical-and-petroleum-facilities
# Generating Q&As for https://engr.ku.edu/civil-environmental-architectural-facilities
# Generating Q&As for https://engr.ku.edu/electrical-engineering-and-computer-science-facilities
# Generating Q&As for https://engr.ku.edu/engineering-physics-facilities
# Generating Q&As for https://engr.ku.edu/mechanical-engineering-facilities
# Generating Q&As for https://engr.ku.edu/news/research
# Generating Q&As for https://engr.ku.edu/faculty-leaders
# Generating Q&As for https://engr.ku.edu/research-support-0
# Generating Q&As for http://ae.engr.ku.edu/facilities
# Generating Q&As for https://engr.ku.edu/graduate-student-funding
# Generating Q&As for https://engr.ku.edu/internal-funding
# Generating Q&As for https://engr.ku.edu/external-funding-faculty
# Generating Q&As for https://engr.ku.edu/ascend-funding-program
# Generating Q&As for https://engr.ku.edu/engineering-ambassadors
# Generating Q&As for https://engr.ku.edu/eaton-learned-and-leep2-spaces
# Generating Q&As for https://engr.ku.edu/room-reservation-form
# Generating Q&As for https://engr.ku.edu/diversity-scholarships
# Generating Q&As for http://me.engr.ku.edu/prospective-graduate-students
# Generating Q&As for https://engr.ku.edu/self-program-apply
# Generating Q&As for https://engr.ku.edu/self-class-2025
# Generating Q&As for https://engr.ku.edu/self-class-2026
# Generating Q&As for https://engr.ku.edu/self-class-2027
# Generating Q&As for https://engr.ku.edu/self-class-2028
# Generating Q&As for https://engr.ku.edu/self-aerospace
# Generating Q&As for https://engr.ku.edu/self-applied-computing
# Generating Q&As for https://engr.ku.edu/self-architectural
# Generating Q&As for https://engr.ku.edu/self-chemical
# Generating Q&As for https://engr.ku.edu/self-civil
# Generating Q&As for https://engr.ku.edu/self-computer-engineering
# Generating Q&As for https://engr.ku.edu/self-computer-science
# Generating Q&As for https://engr.ku.edu/self-electrical-engineering
# Generating Q&As for https://engr.ku.edu/self-mechanical-engineering
# Generating Q&As for https://engr.ku.edu/hsd-2024-winners
# Generating Q&As for https://engr.ku.edu/hsd-faq
# Generating Q&As for https://engr.ku.edu/hsd-2023-winners
# Generating Q&As for https://engr.ku.edu/hsd-partnerships
# Generating Q&As for https://engr.ku.edu/people/heather-abernathy
# Generating Q&As for https://engr.ku.edu/people/neelofar-ahmad
# Generating Q&As for https://engr.ku.edu/people/christopher-anderson
# Generating Q&As for https://engr.ku.edu/people/valentine-baumann
# Generating Q&As for https://engr.ku.edu/people/hal-beckerman
# Generating Q&As for https://engr.ku.edu/people/palvih-bhana
# Generating Q&As for https://engr.ku.edu/people/nathan-fortner
# Generating Q&As for https://engr.ku.edu/people/teresa-fry
# Generating Q&As for https://engr.ku.edu/people/gary-handy
# Generating Q&As for https://engr.ku.edu/people/cody-howard
# Generating Q&As for https://engr.ku.edu/people/jen-jedlicka
# Generating Q&As for https://engr.ku.edu/people/max-jiang-0
# Generating Q&As for https://engr.ku.edu/people/kristi-kamm
# Generating Q&As for https://engr.ku.edu/people/owen-kelly
# Generating Q&As for https://engr.ku.edu/people/remy-lequesne
# Generating Q&As for https://engr.ku.edu/people/lindsey-mccaig
# Generating Q&As for https://engr.ku.edu/people/jeremy-mcleod
# Generating Q&As for https://engr.ku.edu/people/tim-miller
# Generating Q&As for https://engr.ku.edu/people/meredith-morris-whyte
# Generating Q&As for https://engr.ku.edu/people/robert-parsons-phd
# Generating Q&As for https://engr.ku.edu/people/travis-passman
# Generating Q&As for https://engr.ku.edu/people/caleb-regan-0
# Generating Q&As for https://engr.ku.edu/people/mary-rezac-phd
# Generating Q&As for https://engr.ku.edu/people/stefan-sawyer
# Generating Q&As for https://engr.ku.edu/people/steven-d-schrock
# Generating Q&As for https://engr.ku.edu/people/emma-scott
# Generating Q&As for https://engr.ku.edu/people/suzanne-shontz-0
# Generating Q&As for https://engr.ku.edu/people/ryan-siebuhr
# Generating Q&As for https://engr.ku.edu/people/tyler-smith
# Generating Q&As for https://engr.ku.edu/people/elaina-sutley
# Generating Q&As for https://engr.ku.edu/people/amy-wierman
# Generating Q&As for https://engr.ku.edu/unit
# Generating Q&As for https://engr.ku.edu/departmental-faculty-and-staff
# Generating Q&As for https://engr.ku.edu/undergraduate-program-staff
# Generating Q&As for https://engr.ku.edu/graduate-program-staff
# Generating Q&As for https://engr.ku.edu/remote-lab-access-instructions
# Generating Q&As for https://engr.ku.edu/easton-hall-emergency-evacuation-plan
# Generating Q&As for https://engr.ku.edu/learned-hall-emergency-evacuation-plan
# Generating Q&As for https://engr.ku.edu/m2sec-emergency-evacuation-plan
# Generating Q&As for https://engr.ku.edu/eaton-hall-emergency-evacuation-maps
# Generating Q&As for https://engr.ku.edu/learned-hall-floor-maps
# Generating Q&As for https://engr.ku.edu/m2sec-maps
# Generating Q&As for https://engr.ku.edu/digital-signage-submission
# Generating Q&As for https://engr.ku.edu/computer-labs
# Generating Q&As for https://engr.ku.edu/people/dave-glauner
# Generating Q&As for http://bioengr.ku.edu/navigator
# Generating Q&As for http://bioengr.ku.edu/vision-mission
# Generating Q&As for http://bioengr.ku.edu/community
# Generating Q&As for http://bioengr.ku.edu/contact
# Generating Q&As for http://bioengr.ku.edu/faqs
# Generating Q&As for http://bioengr.ku.edu/funding
# Generating Q&As for http://bioengr.ku.edu/beyond-ku
# Generating Q&As for http://bioengr.ku.edu/entrance-requirements-track
# Generating Q&As for http://bioengr.ku.edu/application
# Generating Q&As for http://bioengr.ku.edu/overview
# Generating Q&As for http://bioengr.ku.edu/ms
# Generating Q&As for http://bioengr.ku.edu/accelerated-ms
# Generating Q&As for http://bioengr.ku.edu/master-engineering
# Generating Q&As for http://bioengr.ku.edu/phd
# Generating Q&As for http://bioengr.ku.edu/bioengineering-graduate-programs-2024-25
# Generating Q&As for http://bioengr.ku.edu/bioengineering-courses
# Generating Q&As for http://bioengr.ku.edu/bioimaging
# Generating Q&As for http://bioengr.ku.edu/biomaterials-tissue-engineering
# Generating Q&As for http://bioengr.ku.edu/biomechanics-neural-engineering
# Generating Q&As for http://bioengr.ku.edu/biomedical-product-design-development
# Generating Q&As for http://bioengr.ku.edu/biomolecular-engineering
# Generating Q&As for http://bioengr.ku.edu/computational-bioengineering
# Generating Q&As for http://bioengr.ku.edu/degree-requirements
# Generating Q&As for http://bioengr.ku.edu/forms-documents
# Generating Q&As for http://bioengr.ku.edu/graduating
# Generating Q&As for http://bioengr.ku.edu/biomedical-product-design-certificate
# Generating Q&As for http://bioengr.ku.edu/undergraduate-certificate
# Generating Q&As for http://bioengr.ku.edu/minor-biomedical-engineering
# Generating Q&As for http://bioengr.ku.edu/people/search
# Generating Q&As for http://bioengr.ku.edu/leadership
# Generating Q&As for http://bioengr.ku.edu/core-faculty
# Generating Q&As for http://bioengr.ku.edu/academic-affiliates
# Generating Q&As for http://bioengr.ku.edu/clinical-affiliates
# Generating Q&As for http://bioengr.ku.edu/graduate-students
# Generating Q&As for http://bioengr.ku.edu/staff
# Generating Q&As for http://bioengr.ku.edu/research
# Generating Q&As for http://bioengr.ku.edu/colloquium
# Generating Q&As for http://bioengr.ku.edu/events
# Generating Q&As for http://bioengr.ku.edu/opportunities
# Generating Q&As for http://bioengr.ku.edu/rising-bme-scholars-conference
# Generating Q&As for http://bioengr.ku.edu/donate
# Generating Q&As for https://eecs.ku.edu
# Generating Q&As for https://eecs.ku.edu/navigator
# Generating Q&As for https://eecs.ku.edu/
# Generating Q&As for https://eecs.ku.edu/disciplines
# Generating Q&As for https://eecs.ku.edu/prospective-students
# Generating Q&As for https://eecs.ku.edu/academic-experience
# Generating Q&As for https://eecs.ku.edu/chairs-message
# Generating Q&As for https://eecs.ku.edu/vision-and-mission
# Generating Q&As for https://eecs.ku.edu/ku-eecs-distinguished-service-award
# Generating Q&As for https://eecs.ku.edu/undergraduate-programs
# Generating Q&As for https://eecs.ku.edu/admissions-undergraduate
# Generating Q&As for https://eecs.ku.edu/prospective-students/undergraduate/degree-accreditation
# Generating Q&As for https://eecs.ku.edu/scholarship-tuition
# Generating Q&As for https://eecs.ku.edu/undergraduate-certificate-cybersecurity
# Generating Q&As for https://eecs.ku.edu/graduate-programs
# Generating Q&As for https://eecs.ku.edu/masters-program
# Generating Q&As for https://eecs.ku.edu/phd-program
# Generating Q&As for https://eecs.ku.edu/graduate-funding
# Generating Q&As for https://eecs.ku.edu/data-science-graduate-certificate
# Generating Q&As for https://eecs.ku.edu/rf-systems-engineering-graduate-certificate
# Generating Q&As for https://eecs.ku.edu/electrical-engineering-computer-science-graduate-programs-2024-25
# Generating Q&As for https://eecs.ku.edu/new
# Generating Q&As for https://eecs.ku.edu/new-graduate
# Generating Q&As for https://eecs.ku.edu/new-undergraduate
# Generating Q&As for https://eecs.ku.edu/undergraduate
# Generating Q&As for https://eecs.ku.edu/graduate-students
# Generating Q&As for https://eecs.ku.edu/research-clusters-facilities
# Generating Q&As for https://eecs.ku.edu/masters-programs
# Generating Q&As for https://eecs.ku.edu/phd-programs
# Generating Q&As for https://eecs.ku.edu/defense-notices
# Generating Q&As for https://eecs.ku.edu/current-students/data-science-graduate-certificate
# Generating Q&As for https://eecs.ku.edu/current/rf-systems-engineering-graduate-certificate
# Generating Q&As for https://eecs.ku.edu/eecs-courses
# Generating Q&As for https://eecs.ku.edu/eecs-shop
# Generating Q&As for https://eecs.ku.edu/facilities
# Generating Q&As for https://eecs.ku.edu/eecs-workstation-software
# Generating Q&As for https://eecs.ku.edu/facilities-locations
# Generating Q&As for https://eecs.ku.edu/research-facilities
# Generating Q&As for https://eecs.ku.edu/faculty
# Generating Q&As for https://eecs.ku.edu/staff
# Generating Q&As for https://eecs.ku.edu/advisory-board
# Generating Q&As for https://eecs.ku.edu/giving
# Generating Q&As for https://eecs.ku.edu/tech-help
# Generating Q&As for https://eecs.ku.edu/news
# Generating Q&As for https://eecs.ku.edu/news/article/training-the-next-generation-of-ai-and-microelectronics-innovators
# Generating Q&As for https://eecs.ku.edu/news/article/eecs-students-achieve-success-at-hack-k-state-2024
# Generating Q&As for https://eecs.ku.edu/news/article/eecs-faculty-honored-as-aaas-fellow
# Generating Q&As for https://shopkeeper.eecs.ku.edu/
# Generating Q&As for https://eecs.ku.edu/eecs-publications
# Generating Q&As for https://eecs.ku.edu/ph-d-programs
# Generating Q&As for https://eecs.ku.edu/node/2489
# Generating Q&As for https://eecs.ku.edu/node/2555
# Generating Q&As for https://eecs.ku.edu/news/article/2024/04/26/eecs-honors-excellence-highlights-2024-graduation-dinner-and-awards-ceremony
# Generating Q&As for https://eecs.ku.edu/prospective-students/undergraduate/degree-requirements
# Generating Q&As for https://eecs.ku.edu/deficiency-courses
# Generating Q&As for https://eecs.ku.edu/special-graduate-admissions
# Generating Q&As for https://eecs.ku.edu/computational-science-and-engineering
# Generating Q&As for https://eecs.ku.edu/data-science-and-engineering
# Generating Q&As for https://eecs.ku.edu/cybersecurity
# Generating Q&As for https://eecs.ku.edu/computer-systems-design
# Generating Q&As for https://eecs.ku.edu/language-and-semantics
# Generating Q&As for https://eecs.ku.edu/theory-computing
# Generating Q&As for https://eecs.ku.edu/computing-biosciences
# Generating Q&As for https://eecs.ku.edu/applied-electromagnetics
# Generating Q&As for https://eecs.ku.edu/rf-systems-engineering
# Generating Q&As for https://eecs.ku.edu/communications-systems
# Generating Q&As for https://eecs.ku.edu/radar-systems-and-remote-sensing
# Generating Q&As for https://eecs.ku.edu/signal-processing
# Generating Q&As for https://eecs.ku.edu/people/joy-k-grisafe-gross
# Generating Q&As for https://eecs.ku.edu/people/tanner-willbanks
# Generating Q&As for https://eecs.ku.edu/people/derek-zomer
# Generating Q&As for http://wiki.eecs.ku.edu/
# Generating Q&As for https://eecs.ku.edu/people/tom-colwell
# Generating Q&As for https://eecs.ku.edu/people/david-petr
# Generating Q&As for https://eecs.ku.edu/optical-fiber-measurements-leveraging-coherent-fmcw-techniques
# Generating Q&As for https://eecs.ku.edu/understanding-and-mitigating-security-risks-towards-trustworthy-deep-learning-systems
# Generating Q&As for https://eecs.ku.edu/efficient-index-based-multi-user-scheduling-mobile-mmwave-networks-balancing-channel-quality-and
# Generating Q&As for https://eecs.ku.edu/efficient-and-effective-object-detection-and-recognition-convolutions-transformers
# Generating Q&As for https://eecs.ku.edu/source-separation-using-sparse-bayesian-learning
# Generating Q&As for https://eecs.ku.edu/people/prasad-kulkarni
# Generating Q&As for https://eecs.ku.edu/example-ms-thesis-outline
# Generating Q&As for https://eecs.ku.edu/project-outline
# Generating Q&As for https://eecs.ku.edu/phd-qualifying-exam-topics
# Generating Q&As for https://eecs.ku.edu/defense-notices?page=%2C0
# Generating Q&As for https://eecs.ku.edu/defense-notices?page=%2C1
# Generating Q&As for https://eecs.ku.edu/defense-notices?page=%2C2
# Generating Q&As for https://eecs.ku.edu/defense-notices?page=%2C80
# Generating Q&As for https://app.eecs.ku.edu/mill/emailform.php
# Generating Q&As for https://eecs.ku.edu/cyber-security
# Generating Q&As for http://people.eecs.ku.edu/~agah/
# Generating Q&As for https://eecs.ku.edu/people/shannon-blunt
# Generating Q&As for https://eecs.ku.edu/people/michael-branicky
# Generating Q&As for https://eecs.ku.edu/people/swapan-chakrabarti
# Generating Q&As for http://people.eecs.ku.edu/~demarest/
# Generating Q&As for https://eecs.ku.edu/people/tyrone-duncan
# Generating Q&As for https://eecs.ku.edu/node/1146
# Generating Q&As for https://eecs.ku.edu/people/shima-fardad
# Generating Q&As for https://eecs.ku.edu/people/john-gibbons
# Generating Q&As for https://people.eecs.ku.edu/~jerzygb/index.html
# Generating Q&As for https://eecs.ku.edu/people/sankha-guria
# Generating Q&As for https://eecs.ku.edu/people/rachel-jarvis
# Generating Q&As for https://eecs.ku.edu/people/david-johnson
# Generating Q&As for https://eecs.ku.edu/people/tim-johnson
# Generating Q&As for https://eecs.ku.edu/people/man-kong
# Generating Q&As for https://eecs.ku.edu/people/carlton-leuschen
# Generating Q&As for https://eecs.ku.edu/people/jilu-li
# Generating Q&As for https://eecs.ku.edu/people/brian-mcclendon
# Generating Q&As for https://eecs.ku.edu/people/patrick-mccormick
# Generating Q&As for https://eecs.ku.edu/people/james-mcnaughton
# Generating Q&As for http://people.eecs.ku.edu/~miller/
# Generating Q&As for https://eecs.ku.edu/people/gary-minden
# Generating Q&As for https://eecs.ku.edu/people/jonathan-owen
# Generating Q&As for https://eecs.ku.edu/people/michael-panethiere
# Generating Q&As for https://eecs.ku.edu/people/bozenna-pasik-duncan
# Generating Q&As for https://people.eecs.ku.edu/~esp/
# Generating Q&As for https://eecs.ku.edu/people/glenn-prescott
# Generating Q&As for https://eecs.ku.edu/people/fernando-rodriguez-morales
# Generating Q&As for https://eecs.ku.edu/people/adam-rouse-md-phd
# Generating Q&As for http://people.eecs.ku.edu/~saiedian/
# Generating Q&As for https://eecs.ku.edu/people/alessandro-salandrino
# Generating Q&As for https://eecs.ku.edu/people/jacob-schoonover
# Generating Q&As for http://people.eecs.ku.edu/~shontz
# Generating Q&As for https://eecs.ku.edu/people/james-stiles
# Generating Q&As for https://eecs.ku.edu/people/dongjie-wang
# Generating Q&As for https://eecs.ku.edu/people/han-wang
# Generating Q&As for https://eecs.ku.edu/news/article/eecs-faculty-research-group-makes-waves-at-international-high-performance-computing-conference-for-second-consecutive-year
# Generating Q&As for https://eecs.ku.edu/news/article/ku-jayhackers-triumph-in-international-best-cyber-warrior-competition
# Generating Q&As for https://eecs.ku.edu/news/article/ku-eecs-students-achieve-major-success-at-hack-midwest-2024
# Generating Q&As for https://eecs.ku.edu/news/article/eecs-student-receives-ripples-ubri-impact-award
# Generating Q&As for https://eecs.ku.edu/news/article/ku-eecs-faculty-secures-nsf-funding-for-groundbreaking-research-in-transient-photonics
# Generating Q&As for https://eecs.ku.edu/news/article/eecs-professor-wins-400k-nsf-grant-for-cutting-edge-hardware-security-research
# Generating Q&As for https://eecs.ku.edu/news/article/kuarq-research-group-wins-best-poster-award-at-qcuf-2024
# Generating Q&As for https://eecs.ku.edu/news/article/2024/08/05/professor-heechul-yun-awarded-396000-nsf-grant-data-processing-research
# Generating Q&As for https://eecs.ku.edu/news/article/2024/04/29/eecs-supercomputing-club-shines-2024-single-board-cluster-competition
# Generating Q&As for https://eecs.ku.edu/news/article/2024/04/18/ku-ieee-chapter-shines-ieee-region-5-annual-meeting
# Generating Q&As for https://eecs.ku.edu/news/article/2024/04/16/eecs-professor-branicky-lead-national-effort-ai-engineering
# Generating Q&As for https://eecs.ku.edu/news/article/2024/02/25/professor-david-johnson-publishes-new-book-human-robot-interaction
# Generating Q&As for https://eecs.ku.edu/news/article/2023/11/16/quantum-brilliance-takes-center-stage-sc23-conference
# Generating Q&As for https://eecs.ku.edu/news/article/2023/09/18/eecs-professor-secures-5m-nsf-grant-enhance-5g-network-security-defense
# Generating Q&As for https://eecs.ku.edu/news/article/2023/08/28/eecs-professor-leads-new-15m-virtual-institute-protect-cyberspace
# Generating Q&As for https://eecs.ku.edu/news/article/2023/08/22/eecs-professor-secures-600k-nsf-award-rural-cellular-network-performance-study
# Generating Q&As for https://eecs.ku.edu/news/article/2023/08/18/new-eecs-faculty-members-bring-expertise-data-security-privacy-and-programming-languages
# Generating Q&As for https://eecs.ku.edu/news/article/2023/08/01/eecs-launches-new-social-media-accounts
# Generating Q&As for https://eecs.ku.edu/news/article/2023/07/21/eecs-professors-receive-200000-nsf-award-develop-ai-driven-computer-architecture-learning-tool
# Generating Q&As for https://eecs.ku.edu/news/article/2023/07/20/eecs-faculty-research-group-wins-best-poster-award-doe-quantum-computing-event
# Generating Q&As for https://eecs.ku.edu/news/article/2023/04/21/2023-ku-eecs-keds-award-presented
# Generating Q&As for https://eecs.ku.edu/news/article/2023/04/18/ku-eecs-team-winner-regional-code-thon-competition
# Generating Q&As for https://eecs.ku.edu/news/article/2023/02/16/jayhackers-compete-2023-cyber-defense-competition
# Generating Q&As for https://eecs.ku.edu/news/article/2023/01/09/eecs-faculty-co-pi-395-million-multi-university-research-project
# Generating Q&As for https://eecs.ku.edu/news/article/2023/01/05/eecs-faculty-research-receives-honorable-mention-nsa
# Generating Q&As for https://eecs.ku.edu/news/article/2022/12/17/two-eecs-undergraduate-students-earn-research-awards
# Generating Q&As for https://eecs.ku.edu/news?page=1
# Generating Q&As for https://eecs.ku.edu/news?page=2
# Generating Q&As for https://eecs.ku.edu/news?page=3
# Generating Q&As for https://eecs.ku.edu/news?page=4
# Generating Q&As for https://eecs.ku.edu/news?page=5
# Generating Q&As for https://eecs.ku.edu/news?page=14
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-14-a8d453da0444> in <cell line: 0>()
#       1 for filename in os.listdir(RAW_DATA_PATH):
# ----> 2   with open(f"{RAW_DATA_PATH}{filename}", "r", encoding="utf-8") as f:
#       3     data = json.load(f)
#       4   res = []
#       5   for item in data:
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/raw_data/.ipynb_checkpoints'

# %%
with open(f"{RAW_DATA_PATH}iss_ku_edu.json", "r", encoding="utf-8") as f:
  data = json.load(f)

res = []
for item in data:
  url = item['url']
  text = item['text']
  num_tokens = item['num_tokens']
  user_prompt = user_prompt_template.format(text=text.strip(), url=url)

  print(f'Generating Q&As for {url}')
  client = OpenAI(
  api_key = OPENAI_API_KEY
  )
  try:
    completion = client.chat.completions.create(
      model="gpt-4o-mini",
      store=True,
      messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
      ]
    )
    raw_output = completion.choices[0].message.content
    raw_output = raw_output.strip().replace("```json", "").replace("```", "").strip()
    output = json.loads(raw_output)
    res.extend(output)
  except Exception as e:
    print(f'Failed to generate prompts for: {e}')

  time.sleep(1.5)

with open(f'{QA_DATA_PATH}iss_ku_edu.json', "w", encoding="utf-8") as f:
        json.dump(res, f, indent=2)
# Out:
# Generating Q&As for https://iss.ku.edu
# Generating Q&As for https://iss.ku.edu/navigator
# Generating Q&As for https://iss.ku.edu/
# Generating Q&As for https://iss.ku.edu/contact-us
# Generating Q&As for https://iss.ku.edu/our-services
# Generating Q&As for https://iss.ku.edu/people
# Generating Q&As for https://iss.ku.edu/advising
# Generating Q&As for https://iss.ku.edu/hours-operation-location
# Generating Q&As for https://iss.ku.edu/messages-iss
# Generating Q&As for https://iss.ku.edu/apply
# Generating Q&As for https://iss.ku.edu/jayhawk-semester-students
# Generating Q&As for https://iss.ku.edu/sponsored-students
# Generating Q&As for https://iss.ku.edu/newly-admitted-students
# Generating Q&As for https://iss.ku.edu/student-id-number
# Generating Q&As for https://iss.ku.edu/applying-your-i-20ds-2019-form
# Generating Q&As for https://iss.ku.edu/estimated-cost-attendance
# Generating Q&As for https://iss.ku.edu/proof-finances
# Generating Q&As for https://iss.ku.edu/f-1-transfer
# Generating Q&As for https://iss.ku.edu/pay-sevis-fee
# Generating Q&As for https://iss.ku.edu/apply-visa-newly-admitted
# Generating Q&As for https://iss.ku.edu/register-international-student-orientation
# Generating Q&As for https://iss.ku.edu/arrival-date-newly-admitted
# Generating Q&As for https://iss.ku.edu/finances-newly-admitted
# Generating Q&As for https://iss.ku.edu/students-under-18
# Generating Q&As for https://iss.ku.edu/health-care-insurance-newly-admitted
# Generating Q&As for https://iss.ku.edu/housing-newly-admitted
# Generating Q&As for https://iss.ku.edu/entry-newly-admitted
# Generating Q&As for https://iss.ku.edu/newly-admitted-transportation
# Generating Q&As for https://iss.ku.edu/i94-newly-admitted
# Generating Q&As for https://iss.ku.edu/international-student-orientation
# Generating Q&As for https://iss.ku.edu/enrollment-tuition
# Generating Q&As for https://iss.ku.edu/enrollment-f-students
# Generating Q&As for https://iss.ku.edu/F-1-staying-legal
# Generating Q&As for https://iss.ku.edu/f-1-reduced-course-load
# Generating Q&As for https://iss.ku.edu/F-1-concurrent-enrollment
# Generating Q&As for https://iss.ku.edu/F-1-on-campus-employment
# Generating Q&As for https://iss.ku.edu/f-1-cpt-curricular-practical-training
# Generating Q&As for https://iss.ku.edu/f-1-opt-optional-practical-training
# Generating Q&As for https://iss.ku.edu/f-1-opt-stem-extension
# Generating Q&As for https://iss.ku.edu/f-1-cap-gap
# Generating Q&As for https://iss.ku.edu/f-1-economic-hardship
# Generating Q&As for https://iss.ku.edu/f-1-internship-international-organization
# Generating Q&As for https://iss.ku.edu/f-1-opt-reporting
# Generating Q&As for https://iss.ku.edu/f-2-dependents
# Generating Q&As for https://iss.ku.edu/i-20-extension
# Generating Q&As for https://iss.ku.edu/i-20-requests-or-copies
# Generating Q&As for https://iss.ku.edu/f-1-leaving-ku
# Generating Q&As for https://iss.ku.edu/f-1-regaining-legal-status
# Generating Q&As for https://iss.ku.edu/enrollment-j-students
# Generating Q&As for https://iss.ku.edu/j-1-staying-legal
# Generating Q&As for https://iss.ku.edu/j-1-reduced-course-load
# Generating Q&As for https://iss.ku.edu/j-1-employment-options
# Generating Q&As for https://iss.ku.edu/campus-employment-j-students
# Generating Q&As for https://iss.ku.edu/j-1-academic-training
# Generating Q&As for https://iss.ku.edu/j-1-economic-hardship
# Generating Q&As for https://iss.ku.edu/ds-2019-extension
# Generating Q&As for https://iss.ku.edu/j-1-request-copies-ds-2019-form
# Generating Q&As for https://iss.ku.edu/j-1-transfer-ku
# Generating Q&As for https://iss.ku.edu/J-1-two-year-home-residency-requirement
# Generating Q&As for https://iss.ku.edu/j-2-dependents
# Generating Q&As for https://iss.ku.edu/j-1-change-degree-level
# Generating Q&As for https://iss.ku.edu/j-1-leaving-ku
# Generating Q&As for https://iss.ku.edu/about-your-visa-students
# Generating Q&As for https://iss.ku.edu/apply-visa-student
# Generating Q&As for https://iss.ku.edu/entering-us-f-j-students
# Generating Q&As for https://iss.ku.edu/travel-outside-US-reenter
# Generating Q&As for https://iss.ku.edu/automatic-revalidation-students
# Generating Q&As for https://iss.ku.edu/travel-within-united-states
# Generating Q&As for https://iss.ku.edu/invitation-letter-family
# Generating Q&As for https://iss.ku.edu/jayhawk-semester-program
# Generating Q&As for https://iss.ku.edu/inside-united-states
# Generating Q&As for https://iss.ku.edu/cos-travel-and-re-entry
# Generating Q&As for https://iss.ku.edu/hire-foreign-national
# Generating Q&As for https://iss.ku.edu/immigration-service-fees
# Generating Q&As for https://iss.ku.edu/invite-visiting-scholar
# Generating Q&As for https://iss.ku.edu/request-access-ihawk
# Generating Q&As for https://iss.ku.edu/f-1-opt-stem-opt
# Generating Q&As for https://iss.ku.edu/j-1-scholar-visa-sponsorship
# Generating Q&As for https://iss.ku.edu/visitor-visa
# Generating Q&As for https://iss.ku.edu/about-your-visa-scholar
# Generating Q&As for https://iss.ku.edu/apply-visa-scholars
# Generating Q&As for https://iss.ku.edu/documents-needed-travel-scholar
# Generating Q&As for https://iss.ku.edu/entering-us-scholars
# Generating Q&As for https://iss.ku.edu/renewing-your-passport-united-states
# Generating Q&As for https://iss.ku.edu/travel-signatures-and-ds-2019-reprint-j-scholar
# Generating Q&As for https://iss.ku.edu/j-1-scholars
# Generating Q&As for https://iss.ku.edu/b-1b-2-visitor
# Generating Q&As for https://iss.ku.edu/checklist-new-faculty-and-staff
# Generating Q&As for https://iss.ku.edu/checklist-new-visiting-scholars
# Generating Q&As for https://iss.ku.edu/find-place-live
# Generating Q&As for https://iss.ku.edu/2025-international-student-graduation-celebration
# Generating Q&As for https://iss.ku.edu/events-programs
# Generating Q&As for https://iss.ku.edu/festivals-and-fairs
# Generating Q&As for https://iss.ku.edu/international-student-clubs-and-organizations
# Generating Q&As for https://iss.ku.edu/betty-grimwood-thanksgiving-host-program
# Generating Q&As for https://iss.ku.edu/student-health-insurance
# Generating Q&As for https://iss.ku.edu/employee-health-insurance
# Generating Q&As for https://iss.ku.edu/visiting-scholar-health-insurance
# Generating Q&As for https://iss.ku.edu/how-find-doctor
# Generating Q&As for https://iss.ku.edu/understanding-health-insurance
# Generating Q&As for https://iss.ku.edu/plan-details-id-cards
# Generating Q&As for https://iss.ku.edu/insurance-rates
# Generating Q&As for https://iss.ku.edu/dental-and-vision-insurance
# Generating Q&As for https://iss.ku.edu/search-doctor-uhc-network
# Generating Q&As for https://iss.ku.edu/health-insurance-frequently-asked-questions
# Generating Q&As for https://iss.ku.edu/childcare
# Generating Q&As for https://iss.ku.edu/conversational-english-support
# Generating Q&As for https://iss.ku.edu/drivers-license
# Generating Q&As for https://iss.ku.edu/on-campus-housing
# Generating Q&As for https://iss.ku.edu/off-campus-housing
# Generating Q&As for https://iss.ku.edu/renters-insurance
# Generating Q&As for https://iss.ku.edu/identity-theft
# Generating Q&As for https://iss.ku.edu/campus-safety
# Generating Q&As for https://iss.ku.edu/police
# Generating Q&As for https://iss.ku.edu/saferide-and-safebus
# Generating Q&As for https://iss.ku.edu/when-call-911
# Generating Q&As for https://iss.ku.edu/scams-and-fraud
# Generating Q&As for https://iss.ku.edu/scholarship-loan-information
# Generating Q&As for https://iss.ku.edu/scholarship-policies-and-faqs
# Generating Q&As for https://iss.ku.edu/school-enrollment-children
# Generating Q&As for https://iss.ku.edu/social-security-number-application
# Generating Q&As for https://iss.ku.edu/taxes
# Generating Q&As for https://iss.ku.edu/training-ku-departments
# Generating Q&As for https://iss.ku.edu/airport-lawrence
# Generating Q&As for https://iss.ku.edu/cars
# Generating Q&As for https://iss.ku.edu/public-transporation
# Generating Q&As for https://iss.ku.edu/taxisuber
# Generating Q&As for https://iss.ku.edu/store
# Generating Q&As for https://iss.ku.edu/people/shawn-wettlaufer
# Generating Q&As for https://iss.ku.edu/people/lynne-vanahill
# Generating Q&As for https://iss.ku.edu/people/ginger-jardon
# Generating Q&As for https://iss.ku.edu/people/aaron-mcintyre
# Generating Q&As for https://iss.ku.edu/people/regina-sherrill
# Generating Q&As for https://iss.ku.edu/people/terri-chee
# Generating Q&As for https://iss.ku.edu/people/zulia-ismailova
# Generating Q&As for https://iss.ku.edu/people/katherine-liu
# Generating Q&As for https://iss.ku.edu/people/christopher-mason
# Generating Q&As for https://iss.ku.edu/people/nikola-predolac
# Generating Q&As for https://iss.ku.edu/people/yuki-watanabe
# Generating Q&As for https://iss.ku.edu/people/sarah-zey
# Generating Q&As for https://iss.ku.edu/people/keerthana-balashanmuganan
# Generating Q&As for https://iss.ku.edu/people/laila-kakar
# Generating Q&As for https://iss.ku.edu/people/joanna-thomas
# Generating Q&As for https://iss.ku.edu/united-healthcare-waiver
# Generating Q&As for https://iss.ku.edu/sevis-fee-newly-admitted
# Generating Q&As for https://iss.ku.edu/readmitted_students
# Generating Q&As for https://iss.ku.edu/troubleshooting-ihawk-login-issues
# Generating Q&As for https://iss.ku.edu/3gs
# Generating Q&As for https://iss.ku.edu/waiver-minimum-requirements
# Generating Q&As for https://iss.ku.edu/troubleshooting-ihawk-technical-issues
# Generating Q&As for https://iss.ku.edu/reduced-course-load
# Generating Q&As for https://iss.ku.edu/campus-employment-f-and-j-students
# Generating Q&As for https://iss.ku.edu/apply-visa
# Generating Q&As for https://iss.ku.edu/people/keeli-nelson
# Generating Q&As for https://iss.ku.edu/about-your-visa
# Generating Q&As for https://iss.ku.edu/optional-insurnace-summer
# Generating Q&As for https://iss.ku.edu/health-insurance-gta-gra-ga
# Generating Q&As for https://iss.ku.edu/health-insurance-OPT-AT
# Generating Q&As for https://iss.ku.edu/proof-insurance-j-1-students-not-enrolled-classes
# Generating Q&As for https://iss.ku.edu/proof-insurance-j-2-dependents
# Generating Q&As for https://iss.ku.edu/out-country-waiver

# %% [markdown]
# ## Creating the dataset

# %%
rows = []

for filename in os.listdir(QA_DATA_PATH):
  with open(f"{QA_DATA_PATH}{filename}", "r", encoding="utf-8") as f:
    data = json.load(f)
  for item in data:
    rows.append(item)
df = pd.DataFrame(rows)
df.head(7)

# %%
df['subdomain'] = df['source'].apply(lambda x: urlparse(str(x)).netloc)
df = df[df['subdomain']!='people.eecs.ku.edu']

# %%
train_val_df, test_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df["subdomain"],
    random_state=42
)

train_df, val_df = train_test_split(
    train_val_df,
    test_size=0.125,
    stratify=train_val_df["subdomain"],
    random_state=42
)
